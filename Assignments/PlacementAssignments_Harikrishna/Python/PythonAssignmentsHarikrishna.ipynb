# %% [markdown]
# ### Question 1:
# Write a program that takes a string as input, and counts the frequency of each word in the string, there might be repeated characters in the string. Your task is to find the highest frequency and returns the length of the highest-frequency word.
#
# Note - You have to write at least 2 additional test cases in which your program will run successfully and provide an explanation for the same.
# Example input - string = “write write write all the number from from from 1 to 100”
#
# Example output - 5
#
# Explanation - From the given string we can note that the most frequent words are “write” and “from” and the maximum value of both the values is “write” and its corresponding length is 5

# %%
def find_highest_frequency_word_length(string):
    
    # Split the string into words
    words = string.split()

    # Count the frequency of each word
    word_frequency = {}
    for word in words:
        word_frequency[word] = word_frequency.get(word, 0) + 1

    max_value = max(word_frequency.values())
    filtered_dict = {key: value for key, value in word_frequency.items() if value == max_value}

    word_list=list(filtered_dict.keys())

    max_length = max(len(word) for word in word_list)

    return max_length

for i in range(3):
    string = input() 
    print(find_highest_frequency_word_length(string))

# %% [markdown]
# ### Question 2:
#
# Consider a string to be valid if all characters of the string appear the same number of times. It is also valid if he can remove just one character at the index in the string, and the remaining characters will occur the same number of times. Given a string, determine if it is valid. If so, return YES , otherwise return NO .
#
# Note - You have to write at least 2 additional test cases in which your program will run successfully and provide an explanation for the same.
# Example input 1 - s = “abc”. This is a valid string because frequencies are { “a”: 1, “b”: 1, “c”: 1 }
#
# Example output 1- YES
#
# Example input 2 - s “abcc”. This string is not valid as we can remove only 1 occurrence of “c”. That leaves character frequencies of { “a”: 1, “b”: 1 , “c”: 2 }
#
# Example output 2 - NO

# %%
def valid_str(string):
    occurance = []    
    for i in string:
        occurance.append(string.count(i))
    if len(set(occurance)) == 1:
        return 'YES'
    else:
        return 'NO'
    
for i in range(3):
    string = input() 
    result = valid_str(string)
    print(result)

# %% [markdown]
# ### Question 3:
#
# Write a program, which would download the data from the provided link, and then read the data and convert that into properly structured data and return it in Excel format.
#
# Link - https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json
#
# Data Attributes -
#  * id: Identification Number - int num: Number of the
#  * Pokémon in the official Pokédex - int name: Pokémon name
#  * string img: URL to an image of this Pokémon - string type:
#  * Pokémon type -string height: Pokémon height - float
#  * weight: Pokémon weight - float candy: type of candy used to evolve Pokémon or given
#  * when transferred - string candy_count: the amount of candies required to evolve - int
#  * egg: Number of kilometers to travel to hatch the egg - float spawn_chance
#  * Percentage of spawn chance (NEW) - float avg_spawns: Number of this pokemon on 10.000 spawns (NEW) - int
#
#  spawn_time: Spawns most active at the time on this field. Spawn times are the same for all time zones and are expressed in local time. (NEW) - “minutes: seconds” multipliers: Multiplier of Combat Power (CP) for calculating the CP after evolution See below - list of int weakness: Types of
#
#  Pokémon this Pokémon is weak to - list of strings next_evolution: Number and Name of successive evolutions of Pokémon - list of dict prev_evolution: Number and Name of previous evolutions of Pokémon - - list of dict

# %%
import pandas as pd
import json
import requests
import warnings
warnings.filterwarnings("ignore")

# Fetch JSON data from URL
url = "https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json"
response = requests.get(url)
data = response.json()

# Convert JSON to DataFrame
df = pd.DataFrame(data["pokemon"])

# Convert DataFrame to Excel file
df.to_excel('pokemon_pokedex.xlsx', index=False)

# %% [markdown]
# ### Question 4 -
# Write a program to download the data from the link given below and then read the data and convert the into the proper structure and return it as a CSV file.
#
# Link - https://data.nasa.gov/resource/y77d-th95.json
#
# Note - Write code comments Excepted Output Data Attributes
#  * Name of Earth Meteorite - string id - ID of Earth
#  * Meteorite - int nametype - string recclass - string
#  * mass - Mass of Earth Meteorite - float year - Year at which Earth
#  * Meteorite was hit - datetime format reclat - float recclong - float
#  * point coordinates - list of intwherever needed for code understanding.
#
# Excepted Output Data Attributes
# * Name of Earth Meteorite - string id - ID of Earth
# * Meteorite - int nametype - string recclass - string
# * mass - Mass of Earth Meteorite - float year - Year at which Earth
# * Meteorite was hit - datetime format reclat - float recclong - float
# * point coordinates - list of int

# %%
import pandas as pd
import json
import requests
import warnings
warnings.filterwarnings("ignore")

# Fetch JSON data from URL
url = "https://data.nasa.gov/resource/y77d-th95.json"
response = requests.get(url)
data = response.json()

# Convert JSON to DataFrame
df = pd.DataFrame(data)

# Convert DataFrame to CSV file
df.to_csv('nasa_resource.csv', index=False)

# %% [markdown]
# ### Question 5
#
# Write a program to download the data from the given API link and then extract the following data with proper formatting
#
# Link - http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes
#
# Excepted Output Data Attributes -
# * id - int url - string
# * name - string season
# * int number - int
# * type - string airdate
# * date format airtime
# * 12-hour time format
# * runtime - float
# * average rating - float
# * summary - string
# * without html tags
# * medium image link - string
# * Original image link - string

# %%
import pandas as pd
import json
import requests
import warnings
warnings.filterwarnings("ignore")

# Fetch data
url = "http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes"
response = requests.get(url)
data = response.json()

x=data['_embedded']['episodes']

def extract_dictionary(list_of_dicts, key, value):
    for dictionary in list_of_dicts:
        if key in dictionary and dictionary[key] == value:
            return dictionary
    return None

extracted_dict = extract_dictionary(x, "id", 943065)

import json

# Convert dictionary to JSON
json_data = json.dumps(extracted_dict)

print(json_data)

# %% [markdown]
# ### Question 6 -
#
# Using the data from Question 3, write code to analyze the data and answer the following questions Note
# 1. Draw plots to demonstrate the analysis for the following questions for better visualizations.
# 2. Write code comments wherever required for code understanding
#
# EDA -
# * Get all Pokemons whose spawn rate is less than 5%
# * Get all Pokemons that have less than 4 weaknesses
# * Get all Pokemons that have no multipliers at all
# * Get all Pokemons that do not have more than 2 evolutions
# * Get all Pokemons whose spawn time is less than 300 seconds.
#
# Note - spawn time format is "05:32”, so assume “minute: second” format and perform the analysis.
# * Get all Pokemon who have more than two types of capabilities

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt

#Read data
p_df = pd.read_excel('pokemon_pokedex.xlsx')

print(p_df[p_df['spawn_chance']<0.05]['name'].to_list())

# Plot for the spawn rate of the filtered Pokemon
filtered_pokemon = p_df[p_df['spawn_chance'] < 0.05]

plt.figure(figsize=(20, 6))
plt.bar(filtered_pokemon['name'], filtered_pokemon['spawn_chance'])
plt.xlabel('Pokemon')
plt.ylabel('Spawn Rate')
plt.title('Spawn Rate of Pokemon with Spawn Chance < 5%')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
import ast

p_df['weaknesses'] = p_df['weaknesses'].apply(ast.literal_eval)

#Create a new column for length of weaknesses
p_df['weak_lenghth'] = p_df['weaknesses'].apply(len)

#List of Pokemons that have less than 4 weaknesses
pok_name = p_df[p_df['weak_lenghth']<4]['name'].to_list()
pok_name

# %%
import matplotlib.pyplot as plt

# Filter the Pokemon with less than 4 weaknesses
filtered_pokemon = p_df[p_df['weak_lenghth'] < 4]

# Plot the count of Pokemon with less than 4 weaknesses
plt.figure(figsize=(30, 10))
plt.hist(filtered_pokemon['name'], bins=len(filtered_pokemon), edgecolor='black')
plt.xlabel('Pokemon')
plt.ylabel('Weekness_Count')
plt.title('Count of Pokemon with Less than 4 Weaknesses')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
#Pokemons name who has no multipliers at all(i.e therse is no value)
p_df[p_df.multipliers.isnull()].name.to_list()

# %%
p_df['next_evolution'] = p_df['next_evolution'].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else {})

#Create a new column for length of weaknesses
p_df['evolution_len'] = p_df['next_evolution'].apply(len)

#List of Pokemons that have less than 4 weaknesses
pok_name = p_df[p_df['evolution_len']>2]['name'].to_list()

# Extract minutes and seconds
p_df[['minutes', 'seconds']] = p_df['spawn_time'].str.split(':', expand=True)

# Convert minutes and seconds to numeric data types
p_df['minutes'] = pd.to_numeric(p_df['minutes'], errors='coerce')
p_df['seconds'] = pd.to_numeric(p_df['seconds'], errors='coerce')

# Replace NaN values with 0
p_df['minutes'] = p_df['minutes'].fillna(0)
p_df['seconds'] = p_df['seconds'].fillna(0)

# Convert minutes and seconds to integers
p_df['minutes'] = p_df['minutes'].astype(int)
p_df['seconds'] = p_df['seconds'].astype(int)

# Calculate total seconds
p_df['total_seconds'] = p_df['minutes'] * 60 + p_df['seconds']

# List of Pokemons whose spawn time is less than 300 seconds
p_name = p_df[p_df['total_seconds'] < 300].name.to_list()

p_name

# %%
# Filter the Pokemon whose spawn time is less than 300 seconds
filtered_pokemon = p_df[p_df['total_seconds'] < 300]

# Plot the count of Pokemon with less than 4 weaknesses
plt.figure(figsize=(20, 6))
plt.hist(filtered_pokemon['name'], edgecolor='black')
plt.xlabel('Pokemon')
plt.ylabel('Spawn time')
plt.title('Count of Pokemon whose spawn time is less than 300 seconds')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# Get all Pokemon who have more than two types of capabilities
import ast

p_df['type'] = p_df['type'].apply(ast.literal_eval)

#Create a new column for length of length of type column
p_df['type_len'] = p_df['type'].apply(len)

#List of Pokemons that have more than 2 types of capabilities
pok_name = p_df[p_df['type_len']>2]['name'].to_list()

pok_name        # Hence no one has more than 2 types of capabilities

# %% [markdown]
# ### Question 7 -
#
# Using the data from Question 4, write code to analyze the data and answer the following questions Note -
# 1. Draw plots to demonstrate the analysis for the following questions for better visualizations
# 2. Write code comments wherever required for code understanding
#
# Insights to be drawn -
# * Get all the Earth meteorites that fell before the year 2000
# * Get all the earth meteorites co-ordinates who fell before the year 1970
# * Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more than 10000kg

# %%
# Get all the Earth meteorites that fell before the year 2000

import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
from datetime import datetime

n_df = pd.read_csv('nasa_resource.csv')
ns_df = n_df.copy()

# Convert the 'timestamp' column to datetime data type using datetime
ns_df['year'] = ns_df['year'].apply(lambda x: datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%f") if pd.notnull(x) else None)

# Extract the year
ns_df['Year'] = ns_df['year'].apply(lambda x: x.year if x else None)

# Filter the DataFrame based on conditions
filtered_df = ns_df[(ns_df['fall'] == 'Fell') & (ns_df['Year'] < 2000)]
names = filtered_df['name'].to_list()

names

# %%
# Plot for the Earth meteorites that fell before the year 2000
import matplotlib.pyplot as plt

df = ns_df[(ns_df['fall'] == 'Fell') & (ns_df['Year'] < 2000)]

plt.figure(figsize=(40, 10))
plt.bar(df['name'], df['year'])
plt.xlabel('name')
plt.ylabel('year')
plt.title('the Earth meteorites that fell before the year 2000')
plt.xticks(rotation=90)
plt.show()

# %%
# B. Get all the earth meteorites co-ordinates who fell before the year 1970

import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
from datetime import datetime

n_df = pd.read_csv('nasa_resource.csv')

# Creating a copy for better practice
ns_df = n_df.copy()

# Converting the 'timestamp' column to datetime data type using datetime
ns_df['year'] = ns_df['year'].apply(lambda x: datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%f") if pd.notnull(x) else None)

# Extract the year
ns_df['Year'] = ns_df['year'].apply(lambda x: x.year if x else None)

# Filtering based on conditions
filtered_df = ns_df[(ns_df['fall'] == 'Fell') & (ns_df['Year'] < 1970)]

# names of Earth meteorites that fell before the year 1970
names1 = filtered_df['name'].to_list()

names1

# %%
# meteorites that fell and before the year 1970
filtered_df = ns_df[(ns_df['fall'] == 'Fell') & (ns_df['Year'] < 1970)]

# names of Earth meteorites that fell before the year 1970
names1 = filtered_df['name'].tolist()

# Plot for the count of meteorites
plt.figure(figsize=(40, 6))
plt.hist(names1, bins=len(names1), edgecolor='black')
plt.xlabel('Meteorite Name')
plt.ylabel('Count')
plt.title('Count of Earth Meteorites that Fell Before 1970')
plt.xticks(rotation=90)
plt.show()

# %%
# C. Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more than 10000kg

name_which_has_more_mass = n_df[n_df['mass'] > 10000].name.to_list()

# meteorites with mass > 10,000
filtered_df = n_df[n_df['mass'] > 10000]

# names of meteorites with mass > 10,000
name_which_has_more_mass = filtered_df['name'].tolist()

# Plot the count of meteorites
plt.figure(figsize=(25, 6))
plt.hist(name_which_has_more_mass, bins=len(name_which_has_more_mass), edgecolor='black')
plt.xlabel('Meteorite Name')
plt.ylabel('Count')
plt.title('Count of Meteorites with Mass > 10,000')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Question 8
# Using the data from Question 5, write code the analyze the data and answer the following questions Note -
# 1. Draw plots to demonstrate the analysis for the following questions and better visualizations
# 2. Write code comments wherever required for code understanding
#
# Insights to be drawn -
# * Get all the overall ratings for each season and using plots compare the ratings for all the seasons, like season 1 ratings, season 2, and so on.
# * Get all the episode names, whose average rating is more than 8 for every season
# * Get all the episode names that aired before May 2019
# * Get the episode name from each season with the highest and lowest rating
# * Get the summary for the most popular ( ratings ) episode in every season

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json
import requests
import warnings
warnings.filterwarnings("ignore")

# Fetch JSON data from URL
url = "http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes"
response = requests.get(url)
data = response.json()

x=data['_embedded']['episodes']

def extract_dictionary(list_of_dicts, key, value):
    for dictionary in list_of_dicts:
        if key in dictionary and dictionary[key] == value:
            return dictionary
    return None

extracted_dict = extract_dictionary(x, "id", 2326658)
# print(extracted_dict)

import json

# Convert dictionary to JSON
json_data = json.dumps(extracted_dict)

df=pd.DataFrame(x)

# %%
# Get all the overall ratings for each season and using plots compare the ratings for all the seasons, like season 1 ratings, season 2, and so on.
def rat(val):
    return val['average']

df['rating_value']=df['rating'].apply(rat)
rating = pd.DataFrame(df.groupby(['season'])['rating_value'].sum())
rating.plot(kind='bar',rot=0)

# %%
# Get all the episode names, whose average rating is more than 8 for every season
ep_name = df[df['rating_value']>8]['name'].to_list()
# Plot the count of TV shows
plt.figure(figsize=(20, 4))
plt.hist(ep_name, bins=len(ep_name), edgecolor='black')
plt.xlabel('Episode Name')
plt.ylabel('Count')
plt.title('Count of all the episode names with Rating > 8')
plt.show()

# %%
# Get all the episode names that aired before May 2019

df['airdate'] = pd.to_datetime(df['airdate'])

# Extract year, month, and day
df['year'] = df['airdate'].dt.year
df['month'] = df['airdate'].dt.month
df['day'] = df['airdate'].dt.day

#Applying the condition
filtered_ep_name = df[(df['year'] > 2019) & (df['month'] > 5)]['name'].to_list()

# Plot the count of TV shows
plt.figure(figsize=(10, 6))
plt.hist(filtered_ep_name, bins=len(filtered_ep_name), edgecolor='black')
plt.xlabel('Episode Name')
plt.ylabel('Count')
plt.title('Count of episode names that aired with before May 2019')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# Get the episode name from each season with the highest and lowest rating

# Find episode names with highest rating for each season
highest_rating = df.groupby('season')['rating_value'].idxmax()
fil_ep_name1 = df.loc[highest_rating, ['name', 'season', 'rating_value']]

# Find episode names with lowest rating for each season
lowest_rating = df.groupby('season')['rating_value'].idxmin()
fil_ep_name2 = df.loc[lowest_rating, ['name', 'season', 'rating_value']]

# results
print("Episode names with the highest rating:")
print(fil_ep_name1)

print("\nEpisode names with the lowest rating:")
print(fil_ep_name2)

# Plot for the highest and lowest rated episodes for each season
plt.figure(figsize=(10, 6))
plt.plot(fil_ep_name1['season'], fil_ep_name1['rating_value'], 'bo', label='Highest Rating')
plt.plot(fil_ep_name2['season'], fil_ep_name2['rating_value'], 'ro', label='Lowest Rating')
plt.xlabel('Season')
plt.ylabel('Rating')
plt.title('Highest and Lowest Rated Episodes for Each Season')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Get the summary for the most popular ( ratings ) episode in every season

highest_rating = df.groupby('season')['rating_value'].idxmax()
summ = df.loc[highest_rating, ['summary', 'season', 'rating_value']]

# Plot the distribution of the highest-rated episodes across seasons
plt.figure(figsize=(10, 6))
plt.bar(summ['season'], summ['rating_value'])
plt.xlabel('Season')
plt.ylabel('Rating')
plt.title('Most Popular Episode for Each Season')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Question 9 -
# Write a program to read the data from the following link, perform data analysis and answer the following questions
# Note - 1. Write code comments wherever required for code understanding
#
# Link - https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD
#
# Insights to be drawn -
# * Get all the cars and their types that do not qualify for clean alternative fuel vehicle
# * Get all TESLA cars with the model year, and model type made in Bothell City.
# * Get all the cars that have an electric range of more than 100, and were made after 2015
# * Draw plots to show the distribution between city and electric vehicle type

# %% [markdown]
# ### Question 10
# Write a program to count the number of verbs, nouns, pronouns, and adjectives in a given particular phrase or paragraph, and return their respective count as a dictionary.
# Note -
# 1. Write code comments wherever required for code
# 2. You have to write at least 2 additional test cases in which your program will run successfully and provide an explanation for the same.

# %%
import nltk
from nltk import pos_tag
from nltk.tokenize import word_tokenize

def count_pos_tags(text):
    words = word_tokenize(text)
    tagged_words = pos_tag(words)

    verb_count,noun_count,pronoun_count,adjective_count = 0,0,0,0

    # Iterate over tagged words and count the POS tags
    for word, tag in tagged_words:
        if tag.startswith('VB'):  # Verbs
            verb_count += 1
        elif tag.startswith('NN'):  # Nouns
            noun_count += 1
        elif tag == 'PRP' or tag == 'PRP$':  # Pronouns
            pronoun_count += 1
        elif tag.startswith('JJ'):  # Adjectives
            adjective_count += 1

    # Create a dictionary with the counts
    counts = {
        'nouns': noun_count,
        'pronouns': pronoun_count,
        'verbs': verb_count,
        'adjectives': adjective_count
    }

    return counts

text = "Hey there I'm learning to become a data scientist."
result = count_pos_tags(text)
print(result)
